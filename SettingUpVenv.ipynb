# %%
pip install pyinstaller
# Out:
# ...
#
# ...
#   Using cached altgraph-0.17.4-py2.py3-none-any.whl.metadata (7.3 kB)
# ...
#   Using cached pyinstaller_hooks_contrib-2024.7-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached pefile-2023.2.7-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached pywin32_ctypes-0.2.2-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------- ----------------------- 0.5/1.3 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 16.6 MB/s eta 0:00:00
# Using cached pefile-2023.2.7-py3-none-any.whl (71 kB)
# Using cached pyinstaller_hooks_contrib-2024.7-py2.py3-none-any.whl (341 kB)
# Using cached pywin32_ctypes-0.2.2-py3-none-any.whl (30 kB)
# Using cached altgraph-0.17.4-py2.py3-none-any.whl (21 kB)
# ...

# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.1/16.6 MB 22.9 MB/s eta 0:00:01
#    ------------ --------------------------- 5.2/16.6 MB 54.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.3/16.6 MB 74.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.4/16.6 MB 49.9 MB/s eta 0:00:01
#    --------------------------------- ------ 14.0/16.6 MB 65.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.6/16.6 MB 59.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.6/16.6 MB 59.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.6/16.6 MB 59.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 14.6/16.6 MB 59.5 MB/s eta 0:00:01
# ...

# %%
pip install --force-reinstall -v "panel==1.4.4"
# Out:
# Using pip 24.1.2 from c:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Strategy - working\.venv\lib\site-packages\pip (python 3.9)Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Strategy - working\.venv\Lib\site-packages\~ornado'.
#   You can safely remove it manually.
#   Link requires a different Python (3.9.13 not in: '>=3.10'): https://files.pythonhosted.org/packages/21/c2/0652f4ea0da0f4bd51880d7ed361cece8a9870b43cf5cf24e7b454dbfa19/panel-1.5.0a4-py3-none-any.whl (from https://pypi.org/simple/panel/) (requires-python:>=3.10)
# ...

# %%
pip install --force-reinstall -v "hvplot==0.8.3"
# Out:
# Using pip 24.1.2 from c:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Strategy - working\.venv\lib\site-packages\pip (python 3.9)Note: you may need to restart the kernel to use updated packages.
#
# ...
#   Obtaining dependency information for hvplot==0.8.3 from https://files.pythonhosted.org/packages/80/99/fc345a39244a97f659c7a051f85385be0ba53465d986adf43cfe4109ad3f/hvplot-0.8.3-py2.py3-none-any.whl.metadata
#   Using cached hvplot-0.8.3-py2.py3-none-any.whl.metadata (19 kB)
#   Link requires a different Python (3.9.13 not in: '>=3.10'): https://files.pythonhosted.org/packages/c2/bd/1dded8ae44e8b1fd60a9d50c2d0fd8e098aba20786e7ae65996b7f427d6a/bokeh-3.5.0.dev1-py3-none-any.whl (from https://pypi.org/simple/bokeh/) (requires-python:>=3.10)
# ...

# %%
pip install --force-reinstall -v "matplotlib==3.5.2"
# Out:
# Using pip 24.1.1 from c:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Executable_Strategy\.venv\lib\site-packages\pip (python 3.9)
# ...
#   Obtaining dependency information for matplotlib==3.5.2 from https://files.pythonhosted.org/packages/43/64/1d949d0fab5b83071290a46c93de28cbd8ff15a75b533d6c134012c61e4d/matplotlib-3.5.2-cp39-cp39-win_amd64.whl.metadata
#   Using cached matplotlib-3.5.2-cp39-cp39-win_amd64.whl.metadata (6.7 kB)
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/f1/21/2dc97c5aff32fc3e2472b4ed7125141f1467b71d24f3d356b97864ec7681/fonttools-4.53.0-cp39-cp39-win_amd64.whl.metadata
# ...

# %%
pip install --force-reinstall -v "mplcursors==0.5.3"
# Out:
# Using pip 24.1.2 from c:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Strategy - working\.venv\lib\site-packages\pip (python 3.9)
# ...
#   Using cached mplcursors-0.5.3-py3-none-any.whl
# ...
#   Obtaining dependency information for matplotlib!=3.7.1,>=3.1 from https://files.pythonhosted.org/packages/0c/dd/8270a3114b46831b0faa7fa28e6c78f5e1264eefe2908f0c8869dce4dfbb/matplotlib-3.9.1-cp39-cp39-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/62/5c/08e3a7a35762c8decb6be01c7ec1f4b5f85ef2e2fbb44af87e9caf25a879/contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata
#   Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# ...
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
# ...

# %%
pip install --force-reinstall -v "param==2.0.0"
# Out:
# Using pip 24.1.2 from c:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Strategy - working\.venv\lib\site-packages\pip (python 3.9)
# ...
#   Obtaining dependency information for param==2.0.0 from https://files.pythonhosted.org/packages/7f/7b/6d25e7be5bae8e227f84f6e9f425532f299c0bb8872d5e8c2a9295e46367/param-2.0.0-py3-none-any.whl.metadata
#   Using cached param-2.0.0-py3-none-any.whl.metadata (5.9 kB)
# Using cached param-2.0.0-py3-none-any.whl (116 kB)
# ...
#   Attempting uninstall: param
#     Found existing installation: param 2.1.1
#     Uninstalling param-2.1.1:
#       Removing file or directory c:\users\cw3\bms group\bms re - documents\actuarial\individual actuary folders\clare whitlam\strategy - working\.venv\lib\site-packages\numbergen\
#       Removing file or directory c:\users\cw3\bms group\bms re - documents\actuarial\individual actuary folders\clare whitlam\strategy - working\.venv\lib\site-packages\param-2.1.1.dist-info\
# ...

# %%
pip install --force-reinstall -v "polars==0.18.3"
# Out:
# Using pip 24.1.2 from c:\Users\CW3\BMS Group\BMS Re - Documents\Actuarial\Individual Actuary Folders\Clare Whitlam\Strategy - working\.venv\lib\site-packages\pip (python 3.9)
# ...
#   Obtaining dependency information for polars==0.18.3 from https://files.pythonhosted.org/packages/e6/55/51046d2adc5843d9d24f2fbfd7b34274b9f61e25302d85b18c6c4415dca5/polars-0.18.3-cp37-abi3-win_amd64.whl.metadata
#   Using cached polars-0.18.3-cp37-abi3-win_amd64.whl.metadata (14 kB)
# Using cached polars-0.18.3-cp37-abi3-win_amd64.whl (19.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlwings
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.7 MB 16.4 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 13.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter_bokeh
# Out:
# ...
#   Using cached jupyter_bokeh-4.0.5-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached ipywidgets-8.1.3-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached widgetsnbextension-4.0.11-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached jupyterlab_widgets-3.0.11-py3-none-any.whl.metadata (4.1 kB)
# ...
# Using cached jupyter_bokeh-4.0.5-py3-none-any.whl (148 kB)
# Using cached ipywidgets-8.1.3-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.11-py3-none-any.whl (214 kB)
# Using cached widgetsnbextension-4.0.11-py3-none-any.whl (2.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "altair[all]"
# Out:
# ...
#
#   Using cached altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached altair_tiles-0.3.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached anywidget-0.9.13-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached vega_datasets-0.9.0-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached vegafusion-1.6.9-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached vl_convert_python-1.5.0-cp37-abi3-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached psygnal-0.11.1-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached protobuf-5.27.2-cp39-cp39-win_amd64.whl.metadata (592 bytes)
# ...

# %%
pip install "vegafusion[embed]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install logging
# Out:
# ...
#
#   Using cached logging-0.4.9.6-py3-none-any.whl
# ...

# %%
pip install panel_modal
# Out:
# ...
#   Using cached panel_modal-0.4.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached param-2.1.1-py3-none-any.whl.metadata (7.2 kB)
# ...
# Using cached panel_modal-0.4.0-py3-none-any.whl (7.2 kB)
# Using cached param-2.1.1-py3-none-any.whl (116 kB)
# ...
#   Attempting uninstall: param
#     Found existing installation: param 2.0.0
#     Uninstalling param-2.0.0:
#       Successfully uninstalled param-2.0.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze
# Out:
# altair==5.3.0
# altair_tiles==0.3.0
# altgraph==0.17.4
# anywidget==0.9.13
# asttokens==2.4.1
# attrs==23.2.0
# bleach==6.1.0
# bokeh==3.4.2
# certifi==2024.7.4
# charset-normalizer==3.3.2
# click==8.1.7
# colorama==0.4.6
# colorcet==3.1.0
# comm==0.2.2
# contourpy==1.2.1
# cycler==0.12.1
# debugpy==1.8.2
# decorator==5.1.1
# et-xmlfile==1.1.0
# exceptiongroup==1.2.2
# executing==2.0.1
# fonttools==4.53.1
# holoviews==1.19.1
# hvplot==0.8.3
# idna==3.7
# importlib_metadata==8.1.0
# importlib_resources==6.4.0
# ipykernel==6.29.5
# ipython==8.18.1
# ipywidgets==8.1.3
# jedi==0.19.1
# Jinja2==3.1.4
# jsonschema==4.23.0
# jsonschema-specifications==2023.12.1
# jupyter_bokeh==4.0.5
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# jupyterlab_widgets==3.0.11
# kiwisolver==1.4.5
# linkify-it-py==2.0.3
# logging==0.4.9.6
# Markdown==3.6
# markdown-it-py==3.0.0
# MarkupSafe==2.1.5
# matplotlib==3.9.1
# matplotlib-inline==0.1.7
# mdit-py-plugins==0.4.1
# mdurl==0.1.2
# mercantile==1.2.1
# ...
